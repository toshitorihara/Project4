# %% [markdown]
# # Dependencies

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# keeps the plots in one place. calls image as static pngs
# %matplotlib inline 
import matplotlib.pyplot as plt # side-stepping mpl backend
import matplotlib.gridspec as gridspec # subplots
import mpld3 as mpl

#Import models from scikit learn module:
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %% [markdown]
# # Load and Clean Up the Data

# %%
# Load the data
df = pd.read_csv("data.csv",header = 0)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.drop('id',axis=1,inplace=True)
df.drop('Unnamed: 32',axis=1,inplace=True)
# size of the dataframe
len(df)
# Out:
# 569

# %%
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# df.describe()

# %%
# Split our preprocessed data into our features and target arrays
y = df.pop('diagnosis')
X = df

# %%
# Split the preprocessed data into a training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
from sklearn.preprocessing import StandardScaler
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
import tensorflow as tf
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units = 50, activation = 'relu' , input_dim = 30)) 

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units = 50, activation = 'relu' , input_dim = 30)) 

# Output layer
nn_model.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 50)                1550
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 4,151
# Trainable params: 4,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss = 'binary_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled , y_train , epochs = 100)
# Out:
# Train on 426 samples
# Epoch 1/100
# 426/426 [==============================] - 0s 117us/sample - loss: 0.0469 - accuracy: 0.9859
# Epoch 2/100
# 426/426 [==============================] - 0s 70us/sample - loss: 0.0436 - accuracy: 0.9883
# Epoch 3/100
# 426/426 [==============================] - 0s 59us/sample - loss: 0.0403 - accuracy: 0.9883
# Epoch 4/100
# 426/426 [==============================] - 0s 47us/sample - loss: 0.0373 - accuracy: 0.9883
# Epoch 5/100
# 426/426 [==============================] - 0s 52us/sample - loss: 0.0360 - accuracy: 0.9930
# Epoch 6/100
# 426/426 [==============================] - 0s 42us/sample - loss: 0.0327 - accuracy: 0.9930
# Epoch 7/100
# 426/426 [==============================] - 0s 103us/sample - loss: 0.0303 - accuracy: 0.9930
# Epoch 8/100
# 426/426 [==============================] - 0s 70us/sample - loss: 0.0282 - accuracy: 0.9930
# Epoch 9/100
# 426/426 [==============================] - 0s 94us/sample - loss: 0.0261 - accuracy: 0.9930
# Epoch 10/100
# 426/426 [==============================] - 0s 77us/sample - loss: 0.0247 - accuracy: 0.9930
# Epoch 11/100
# 426/426 [==============================] - 0s 101us/sample - loss: 0.0229 - accuracy: 0.9930
# Epoch 12/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.0209 - accuracy: 0.9930
# Epoch 13/100
# 426/426 [==============================] - 0s 119us/sample - loss: 0.0197 - accuracy: 0.9930
# Epoch 14/100
# 426/426 [==============================] - 0s 103us/sample - loss: 0.0180 - accuracy: 0.9930
# Epoch 15/100
# 426/426 [==============================] - 0s 78us/sample - loss: 0.0171 - accuracy: 0.9930
# Epoch 16/100
# 426/426 [==============================] - 0s 105us/sample - loss: 0.0154 - accuracy: 0.9930
# Epoch 17/100
# 426/426 [==============================] - 0s 87us/sample - loss: 0.0147 - accuracy: 0.9930
# Epoch 18/100
# 426/426 [==============================] - 0s 70us/sample - loss: 0.0132 - accuracy: 0.9953
# Epoch 19/100
# 426/426 [==============================] - 0s 129us/sample - loss: 0.0125 - accuracy: 0.9930
# Epoch 20/100
# 426/426 [==============================] - 0s 82us/sample - loss: 0.0128 - accuracy: 0.9977
# Epoch 21/100
# 426/426 [==============================] - 0s 68us/sample - loss: 0.0115 - accuracy: 0.9977
# Epoch 22/100
# 426/426 [==============================] - 0s 70us/sample - loss: 0.0099 - accuracy: 1.0000
# Epoch 23/100
# 426/426 [==============================] - 0s 63us/sample - loss: 0.0090 - accuracy: 1.0000
# Epoch 24/100
# 426/426 [==============================] - 0s 59us/sample - loss: 0.0085 - accuracy: 1.0000
# Epoch 25/100
# 426/426 [==============================] - 0s 70us/sample - loss: 0.0077 - accuracy: 1.0000
# Epoch 26/100
# 426/426 [==============================] - 0s 70us/sample - loss: 0.0074 - accuracy: 1.0000
# Epoch 27/100
# 426/426 [==============================] - 0s 63us/sample - loss: 0.0068 - accuracy: 1.0000
# Epoch 28/100
# 426/426 [==============================] - 0s 61us/sample - loss: 0.0064 - accuracy: 1.0000
# Epoch 29/100
# 426/426 [==============================] - 0s 73us/sample - loss: 0.0059 - accuracy: 1.0000
# Epoch 30/100
# 426/426 [==============================] - 0s 73us/sample - loss: 0.0057 - accuracy: 1.0000
# Epoch 31/100
# 426/426 [==============================] - 0s 70us/sample - loss: 0.0053 - accuracy: 1.0000
# Epoch 32/100
# 426/426 [==============================] - 0s 68us/sample - loss: 0.0047 - accuracy: 1.0000
# Epoch 33/100
# 426/426 [==============================] - 0s 54us/sample - loss: 0.0049 - accuracy: 1.0000
# Epoch 34/100
# 426/426 [==============================] - 0s 65us/sample - loss: 0.0043 - accuracy: 1.0000
# Epoch 35/100
# 426/426 [==============================] - 0s 68us/sample - loss: 0.0041 - accuracy: 1.0000
# Epoch 36/100
# 426/426 [==============================] - 0s 77us/sample - loss: 0.0039 - accuracy: 1.0000
# Epoch 37/100
# 426/426 [==============================] - 0s 87us/sample - loss: 0.0036 - accuracy: 1.0000
# Epoch 38/100
# 426/426 [==============================] - 0s 77us/sample - loss: 0.0034 - accuracy: 1.0000
# Epoch 39/100
# 426/426 [==============================] - 0s 92us/sample - loss: 0.0032 - accuracy: 1.0000
# Epoch 40/100
# 426/426 [==============================] - 0s 96us/sample - loss: 0.0031 - accuracy: 1.0000
# Epoch 41/100
# 426/426 [==============================] - 0s 91us/sample - loss: 0.0029 - accuracy: 1.0000
# Epoch 42/100
# 426/426 [==============================] - 0s 91us/sample - loss: 0.0027 - accuracy: 1.0000
# Epoch 43/100
# 426/426 [==============================] - 0s 84us/sample - loss: 0.0027 - accuracy: 1.0000
# Epoch 44/100
# 426/426 [==============================] - 0s 131us/sample - loss: 0.0026 - accuracy: 1.0000
# Epoch 45/100
# 426/426 [==============================] - 0s 117us/sample - loss: 0.0024 - accuracy: 1.0000
# Epoch 46/100
# 426/426 [==============================] - 0s 118us/sample - loss: 0.0022 - accuracy: 1.0000
# Epoch 47/100
# 426/426 [==============================] - 0s 124us/sample - loss: 0.0021 - accuracy: 1.0000
# Epoch 48/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.0020 - accuracy: 1.0000
# Epoch 49/100
# 426/426 [==============================] - 0s 143us/sample - loss: 0.0019 - accuracy: 1.0000
# Epoch 50/100
# 426/426 [==============================] - 0s 140us/sample - loss: 0.0019 - accuracy: 1.0000
# Epoch 51/100
# 426/426 [==============================] - 0s 124us/sample - loss: 0.0018 - accuracy: 1.0000
# Epoch 52/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.0018 - accuracy: 1.0000
# Epoch 53/100
# 426/426 [==============================] - 0s 143us/sample - loss: 0.0017 - accuracy: 1.0000
# Epoch 54/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.0016 - accuracy: 1.0000
# Epoch 55/100
# 426/426 [==============================] - 0s 114us/sample - loss: 0.0015 - accuracy: 1.0000
# Epoch 56/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.0014 - accuracy: 1.0000
# Epoch 57/100
# 426/426 [==============================] - 0s 118us/sample - loss: 0.0014 - accuracy: 1.0000
# Epoch 58/100
# 426/426 [==============================] - 0s 160us/sample - loss: 0.0013 - accuracy: 1.0000
# Epoch 59/100
# 426/426 [==============================] - 0s 126us/sample - loss: 0.0013 - accuracy: 1.0000
# Epoch 60/100
# 426/426 [==============================] - 0s 90us/sample - loss: 0.0013 - accuracy: 1.0000
# Epoch 61/100
# 426/426 [==============================] - 0s 87us/sample - loss: 0.0012 - accuracy: 1.0000
# Epoch 62/100
# 426/426 [==============================] - 0s 82us/sample - loss: 0.0012 - accuracy: 1.0000
# Epoch 63/100
# 426/426 [==============================] - 0s 199us/sample - loss: 0.0011 - accuracy: 1.0000
# Epoch 64/100
# 426/426 [==============================] - 0s 108us/sample - loss: 0.0011 - accuracy: 1.0000
# Epoch 65/100
# 426/426 [==============================] - 0s 87us/sample - loss: 0.0011 - accuracy: 1.0000
# Epoch 66/100
# 426/426 [==============================] - 0s 96us/sample - loss: 0.0010 - accuracy: 1.0000
# Epoch 67/100
# 426/426 [==============================] - 0s 82us/sample - loss: 9.7198e-04 - accuracy: 1.0000
# Epoch 68/100
# 426/426 [==============================] - 0s 56us/sample - loss: 9.4426e-04 - accuracy: 1.0000
# Epoch 69/100
# 426/426 [==============================] - 0s 77us/sample - loss: 9.1114e-04 - accuracy: 1.0000
# Epoch 70/100
# 426/426 [==============================] - 0s 77us/sample - loss: 8.7401e-04 - accuracy: 1.0000
# Epoch 71/100
# 426/426 [==============================] - 0s 103us/sample - loss: 8.6412e-04 - accuracy: 1.0000
# Epoch 72/100
# 426/426 [==============================] - 0s 63us/sample - loss: 8.6436e-04 - accuracy: 1.0000
# Epoch 73/100
# 426/426 [==============================] - 0s 89us/sample - loss: 8.1952e-04 - accuracy: 1.0000
# Epoch 74/100
# 426/426 [==============================] - 0s 59us/sample - loss: 8.6799e-04 - accuracy: 1.0000
# Epoch 75/100
# 426/426 [==============================] - 0s 89us/sample - loss: 7.9179e-04 - accuracy: 1.0000
# Epoch 76/100
# 426/426 [==============================] - 0s 68us/sample - loss: 7.3613e-04 - accuracy: 1.0000
# Epoch 77/100
# 426/426 [==============================] - 0s 56us/sample - loss: 7.3718e-04 - accuracy: 1.0000
# Epoch 78/100
# 426/426 [==============================] - 0s 75us/sample - loss: 6.9707e-04 - accuracy: 1.0000
# Epoch 79/100
# 426/426 [==============================] - 0s 59us/sample - loss: 6.6307e-04 - accuracy: 1.0000
# Epoch 80/100
# 426/426 [==============================] - 0s 52us/sample - loss: 6.4591e-04 - accuracy: 1.0000
# Epoch 81/100
# 426/426 [==============================] - 0s 66us/sample - loss: 6.4600e-04 - accuracy: 1.0000
# Epoch 82/100
# 426/426 [==============================] - 0s 82us/sample - loss: 6.2616e-04 - accuracy: 1.0000
# Epoch 83/100
# 426/426 [==============================] - 0s 91us/sample - loss: 6.0412e-04 - accuracy: 1.0000
# Epoch 84/100
# 426/426 [==============================] - 0s 87us/sample - loss: 5.8986e-04 - accuracy: 1.0000
# Epoch 85/100
# 426/426 [==============================] - 0s 84us/sample - loss: 5.7284e-04 - accuracy: 1.0000
# Epoch 86/100
# 426/426 [==============================] - 0s 89us/sample - loss: 5.5759e-04 - accuracy: 1.0000
# Epoch 87/100
# 426/426 [==============================] - 0s 79us/sample - loss: 5.5621e-04 - accuracy: 1.0000
# Epoch 88/100
# 426/426 [==============================] - 0s 66us/sample - loss: 5.1802e-04 - accuracy: 1.0000
# Epoch 89/100
# 426/426 [==============================] - 0s 61us/sample - loss: 5.1588e-04 - accuracy: 1.0000
# Epoch 90/100
# 426/426 [==============================] - 0s 82us/sample - loss: 5.5231e-04 - accuracy: 1.0000
# Epoch 91/100
# 426/426 [==============================] - 0s 75us/sample - loss: 5.2199e-04 - accuracy: 1.0000
# Epoch 92/100
# 426/426 [==============================] - 0s 75us/sample - loss: 4.8742e-04 - accuracy: 1.0000
# Epoch 93/100
# 426/426 [==============================] - 0s 77us/sample - loss: 4.6121e-04 - accuracy: 1.0000
# Epoch 94/100
# 426/426 [==============================] - 0s 80us/sample - loss: 4.4965e-04 - accuracy: 1.0000
# Epoch 95/100
# 426/426 [==============================] - 0s 77us/sample - loss: 4.3278e-04 - accuracy: 1.0000
# Epoch 96/100
# 426/426 [==============================] - 0s 77us/sample - loss: 4.2757e-04 - accuracy: 1.0000
# Epoch 97/100
# 426/426 [==============================] - 0s 77us/sample - loss: 4.1441e-04 - accuracy: 1.0000
# Epoch 98/100
# 426/426 [==============================] - 0s 94us/sample - loss: 4.0222e-04 - accuracy: 1.0000
# Epoch 99/100
# 426/426 [==============================] - 0s 78us/sample - loss: 3.9164e-04 - accuracy: 1.0000
# Epoch 100/100
# 426/426 [==============================] - 0s 112us/sample - loss: 3.8256e-04 - accuracy: 1.0000

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 143/143 - 0s - loss: 0.1323 - accuracy: 0.9650
# Loss: 0.1323292113684274, Accuracy: 0.9650349617004395
